# %%
# Tokenize for Validation, annual_reports folder

# %%
import os
import pandas as pd
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

# Specifying the subfolders
annual_reports_folder = 'annual_reports'


# Initialize an empty list to store the DataFrame for each file
df_list = []

# Looping through each file in the annual reports folder
# Give correct folder path for validation folder
for annual_report_file_name in os.listdir(f"/home/student/Desktop/FNS_dataset/validation/{annual_reports_folder}"):
    # Constructing the file paths
    annual_report_path = f"/home/student/Desktop/FNS_dataset/validation/{annual_reports_folder}/{annual_report_file_name}"

    # Extract the base name without extension (e.g., '10' from '10.txt', in below [0] has root name and [1] will have extension part)
    base_name = os.path.splitext(annual_report_file_name)[0]

   

    # Reading the annual report text into a string
    with open(annual_report_path, 'r', encoding='utf-8') as file:
        annual_report_text = file.read()


        # Tokenizing the text into sentences
        annual_report_sentences = sent_tokenize(annual_report_text)
        

    # Filter out sentences with length less than 5
    filtered_sentences = [sentence for sentence in annual_report_sentences if len(word_tokenize(sentence)) >= 5]
   
    # Create a DataFrame with the filtered sentences and labels columns
    df = pd.DataFrame({'sentence': filtered_sentences})

    preprocessed_output_path = '/home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output'
    os.makedirs(preprocessed_output_path, exist_ok=True)

    # Save the DataFrame to a CSV file with an escape character '|'
    output_file_name = f"{base_name}_tokenized.csv"
    output_file_path = f"/home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/{output_file_name}"
    df.to_csv(output_file_path, index=False, escapechar='|')

    # Display the processed(here labelling) DataFrame
    print(f"Processed data saved to {output_file_path}")

    # Append the DataFrame to the list
    df_list.append(df)

# Concatenate all DataFrames in the list
final_df = pd.concat(df_list, ignore_index=True)

# Save the final DataFrame to a CSV file
final_output_file_path = "/home/student/Desktop/NLP_Output/final_validation_sen_tokenize_data_combined.csv"
final_df.to_csv(final_output_file_path, index=False, escapechar='|')

# Display the final processed DataFrame
print(f"Final processed data saved to {final_output_file_path}")
# Out:
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32020_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30962_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32717_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32248_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31817_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32771_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31678_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31242_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32051_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31005_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32773_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32220_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31855_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30822_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31358_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31462_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/33057_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32376_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32408_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32092_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32149_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30821_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30922_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32150_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31648_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30920_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31540_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31631_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31109_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32186_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30899_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31959_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31926_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31573_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31478_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31277_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30954_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30855_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32170_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31854_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31202_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31969_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30782_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31914_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31608_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31040_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30800_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32553_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30895_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30887_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31513_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31146_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32098_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32349_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32168_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32394_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32879_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30813_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32540_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31623_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31023_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/33036_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30854_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30819_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30947_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31568_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31036_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31831_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32071_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32179_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31440_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/33155_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31646_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31329_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31038_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31872_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31452_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31834_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31589_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32562_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30838_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31546_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31617_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30808_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32657_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31319_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30903_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31026_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32939_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31290_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31850_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31007_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32004_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32602_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30897_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32286_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31037_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32135_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31013_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30856_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32355_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32651_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31628_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30783_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32378_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32538_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32333_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32848_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32384_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31851_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31469_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30795_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32859_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31699_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30907_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/33070_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30943_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31811_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32072_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32165_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/33130_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31265_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31633_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32954_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30966_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31610_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30894_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32392_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31955_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31316_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30913_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32185_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30785_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32143_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31866_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32176_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30841_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31843_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30940_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32548_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31517_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31601_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31033_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32061_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30927_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31399_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31014_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30820_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31042_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31705_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32129_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/33039_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32389_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/33090_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31984_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31938_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32032_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32966_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32155_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32693_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30781_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31664_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31315_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32197_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32139_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31260_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31204_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31127_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31022_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30991_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30858_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30852_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31114_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30904_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31677_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30830_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32874_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32113_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32810_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32136_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32648_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/33098_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31857_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30778_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30817_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30902_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32964_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31063_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30816_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31292_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31474_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31484_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32272_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/33097_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32236_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32380_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32531_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31604_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31755_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31940_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31058_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32684_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30886_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31220_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32343_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30960_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31939_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/33037_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32044_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32849_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32452_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32217_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32599_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32792_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31769_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31950_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32021_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31632_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32144_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/33154_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31839_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30982_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31659_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31828_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31274_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30941_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31050_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32561_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31983_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32067_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31595_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32482_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/33029_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32424_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32345_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32034_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31879_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31034_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31685_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32183_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31012_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31424_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32157_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31015_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31201_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31333_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32583_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30790_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31948_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30952_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31979_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32825_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30779_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31824_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31008_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/33038_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32107_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/33035_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31061_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30950_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30796_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32557_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32223_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31794_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32854_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31203_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32116_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31655_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31681_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32556_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32734_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31784_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32543_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30968_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31383_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31650_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32616_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32437_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32141_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32886_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30815_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32926_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32597_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31306_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31271_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31757_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31506_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32359_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32196_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31512_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31064_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31224_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30901_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30874_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32809_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32555_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32025_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31508_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31846_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31620_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32042_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31165_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/33083_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32074_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31074_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/33027_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31889_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30967_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31105_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32688_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32340_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31076_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30777_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/33054_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32163_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31059_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32865_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30924_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31053_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31987_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32480_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31654_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31844_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31942_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30849_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30965_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/33018_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31567_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32560_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32609_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30850_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32623_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30946_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32097_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31509_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32541_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30888_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32229_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32936_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31618_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32148_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32180_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31634_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32177_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31336_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32156_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32134_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32190_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31661_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31492_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31363_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30866_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31101_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/33053_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/30948_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32140_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32545_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31766_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31514_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31254_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31970_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/31031_tokenized.csv
# Processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_output/32414_tokenized.csv
# Final processed data saved to /home/student/Desktop/NLP_Output/final_validation_sen_tokenize_data_combined.csv

# %%
# Preprocessing on tokenized validation data

# %%
import os
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import string
import nltk
import re

# Download NLTK resources
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')

# Specify the subfolders
# labelled_output_folder is where sentences of anuual_reports are stores(this is output o first part(sentence tokenization of documents) of validation annual_reports)
labelled_output_folder = 'final_validation_sen_tokenize_output'
preprocessed_output_folder = 'final_validation_preprocess_output'

# Create the preprocessed output folder if it doesn't exist,
preprocessed_output_path = f"/home/student/Desktop/NLP_Output/{preprocessed_output_folder}"
os.makedirs(preprocessed_output_path, exist_ok=True)

# Punctuation and Special Character Removal 
def remove_punctuation(text):
    return ''.join(char for char in text if char.isalnum() or char.isspace())


lemmatizer = WordNetLemmatizer()

# POS Tagging
def pos_tag_sentence(sentence):
    try:
        tokens = word_tokenize(sentence)
        pos_tags = pos_tag(tokens)
        return pos_tags
    except Exception as e:
        print(f"Error in pos_tag_sentence: {e}")
        return []
# Lemmatization
def lemmatize_sentence(pos_tags):
    try:
        lemmatizer = WordNetLemmatizer()
        stop_words = set(stopwords.words('english'))
        lemmatized_tokens = [lemmatizer.lemmatize(word) for word, tag in pos_tags if word.lower() not in stop_words and word not in string.punctuation]
        cleaned_sentence = ' '.join(lemmatized_tokens)
        return cleaned_sentence
    except Exception as e:
        print(f"Error in lemmatize_sentence: {e}")
        return ''

# Remove non-printable characters using regex
def clean_text(text):
    return re.sub(r'[^ -~]', '', text)

# Stop Word Removal
stop_words = set(stopwords.words('english'))

def remove_stopwords(text):
    return ' '.join(word for word in text.split() if word.lower() not in stop_words)

# Loop through each file in the labelled_output folder
for labelled_file_name in os.listdir(f"/home/student/Desktop/NLP_Output/{labelled_output_folder}"):
    # Construct the file paths
    labelled_file_path = f"/home/student/Desktop/NLP_Output/{labelled_output_folder}/{labelled_file_name}"

    try:
        # Read the labelled output text into a DataFrame
        df_labelled = pd.read_csv(labelled_file_path, escapechar='|')

        # Drop rows with missing or empty sentences
        df_labelled = df_labelled.dropna(subset=['sentence'])
        df_labelled = df_labelled[df_labelled['sentence'] != '']

        # Perform preprocessing on each sentence
        df_labelled['pos_tags'] = df_labelled['sentence'].apply(pos_tag_sentence)
        df_labelled['cleaned_sentence'] = df_labelled['pos_tags'].apply(lemmatize_sentence)
        df_labelled['cleaned_sentence'] = df_labelled['cleaned_sentence'].apply(clean_text)
        df_labelled['preprocessed_sentence'] = df_labelled['cleaned_sentence'].apply(remove_punctuation)
        df_labelled['preprocessed_sentence'] = df_labelled['preprocessed_sentence'].apply(remove_stopwords)

        # Create a DataFrame for preprocessed output
        df_preprocessed = pd.DataFrame({
            'sentence': df_labelled['sentence'],
            # 'label': df_labelled['label'],
            'preprocessed_sentence': df_labelled['preprocessed_sentence'],
            # 'pos_tags': df_labelled['pos_tags'],
        })

        # Save the preprocessed DataFrame to a CSV file with an escape character '|'
        preprocessed_file_name = f"{os.path.splitext(labelled_file_name)[0]}_preprocess.csv"
        preprocessed_file_path = f"{preprocessed_output_path}/{preprocessed_file_name}"
        df_preprocessed.to_csv(preprocessed_file_path, index=False, escapechar='|')

        # Display the processed DataFrame
        print(f"Preprocessed data saved to {preprocessed_file_path}")

    except Exception as e:
        print(f"Error processing file: {labelled_file_name}")
        print(e)
# Out:
# [nltk_data] Downloading package punkt to /home/student/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/student/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /home/student/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/student/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32879_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31053_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30966_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32139_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31462_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30800_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32349_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31050_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30954_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32384_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32229_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30777_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31036_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32359_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/33057_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31474_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32044_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31681_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30960_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/33083_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32186_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30887_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30967_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31655_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31984_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32717_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32143_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32693_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31846_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32651_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32116_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31513_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32032_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30816_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32248_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32560_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31633_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31023_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30913_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32179_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32966_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31076_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32343_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31146_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31811_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31879_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31831_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32602_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30817_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31265_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30927_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32809_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32149_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31987_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31064_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32004_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30852_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31478_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30903_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31839_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32688_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32936_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32150_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30866_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31015_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30819_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31628_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32129_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30795_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31851_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31508_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/33037_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32954_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30796_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32170_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31889_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/33097_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31260_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31424_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32414_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31292_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31358_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32773_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31939_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30897_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31617_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32597_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32141_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31705_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32034_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31646_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31127_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32556_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32223_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31979_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31634_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32792_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32561_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31452_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31959_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30940_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31632_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31271_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31042_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31031_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31834_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32177_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32107_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31755_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32136_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31757_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32609_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32355_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32020_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31336_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31854_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31058_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31866_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31604_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31517_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32074_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31650_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31654_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30922_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31610_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32408_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32874_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31022_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31664_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32562_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/33029_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30904_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32548_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30781_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32134_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30899_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30946_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32392_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30968_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32378_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32854_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30850_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31677_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31506_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/33130_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31165_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30856_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31608_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31484_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32657_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30901_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31855_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32394_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32345_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32155_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32144_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31114_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30920_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32061_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/33054_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32771_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30965_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31595_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31824_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32939_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31007_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/33018_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32810_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32272_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32865_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32623_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31659_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30950_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31329_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31623_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32217_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32825_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32176_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32859_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30895_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32157_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32480_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31926_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32531_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32886_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32165_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31399_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31061_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31678_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31850_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31940_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30855_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31012_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31950_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32555_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32376_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31589_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31290_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31383_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31661_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31319_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/33035_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32452_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30820_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32648_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32135_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31631_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30943_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31567_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31254_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31033_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/33038_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31938_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31983_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32543_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32437_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31514_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30790_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31224_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32196_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30924_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32190_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32156_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30841_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31512_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31685_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31601_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30808_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31699_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30858_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32849_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/33154_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31546_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31037_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30849_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32097_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/33155_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31914_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31109_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30813_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31872_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31492_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31540_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30838_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31005_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30785_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/33036_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31074_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31568_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31844_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32541_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31769_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31013_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30907_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31315_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31274_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31817_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30886_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32538_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32098_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31026_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32684_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32180_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32148_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32113_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30948_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30815_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31220_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30830_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32183_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32168_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31942_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32236_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31202_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31843_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31316_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32021_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32072_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31063_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31509_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31766_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31277_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30821_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32051_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31306_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30962_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32424_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30778_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31101_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31040_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31034_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32185_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31333_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31008_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30991_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31059_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/33053_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32042_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31038_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31469_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32848_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32163_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32286_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30874_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32067_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31204_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32333_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31363_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31620_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31201_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32599_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31970_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30902_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31573_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30779_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32389_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30822_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31784_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32380_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31203_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32540_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/33090_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32557_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31618_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32092_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30952_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32340_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30941_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30947_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/33070_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30783_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32197_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31014_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32583_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32220_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30894_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/33039_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31794_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31440_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31828_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32071_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32616_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31955_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32140_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30888_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31105_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32482_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30854_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31948_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32926_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/33098_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32734_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32964_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31969_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31242_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32553_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30982_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31857_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30782_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32545_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31648_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32025_tokenized_preprocess.csv
# Preprocessed data saved to /home/student/Desktop/NLP_Output/final_validation_preprocess_output/33027_tokenized_preprocess.csv

# %%
# Feature extraction on preprocessed validation data

# %%
import os
import pandas as pd
from nltk import word_tokenize, pos_tag
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import math
import numpy as np
import re
from nltk.corpus import wordnet

def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return None




# Function to calculate Sentence Length
def calculate_sentence_length(sentence, longest_sentence_length):
    try:
        # Exclude numeric values from tokens
        tokens = [word for word in word_tokenize(str(sentence)) if not word.isnumeric()]

        if not tokens:  # Check if tokens list is empty after excluding numerics
            return format(0.0, '.4f')

        return format(len(tokens) / longest_sentence_length, '.4f')

    except (TypeError, AttributeError) as e:
        print(f"Error in tokenization for sentence: {sentence}. Error: {e}")
        return format(0.0, '.4f')  



# Function to calculate Sentence Position
def calculate_sentence_position(sentence_index, total_sentences):
    try:
        if sentence_index == 0 or sentence_index == total_sentences - 1:
            return 1
        else:
            return format((total_sentences - sentence_index) / total_sentences, '.4f')

    except (TypeError, AttributeError) as e:
        print(f"Error in calculating sentence position for index {sentence_index}. Error: {e}")
        return 0.0  


# Function to calculate Proper Nouns
def calculate_proper_nouns(sentence):
    try:
        tags = pos_tag(word_tokenize(str(sentence)))
        proper_noun_count = sum(1 for word, tag in tags if tag == 'NNP')
        return format(proper_noun_count / len(word_tokenize(str(sentence))),'.4f')

    except (TypeError, AttributeError) as e:
        print(f"Error in POS tagging for sentence: {sentence}. Error: {e}")
        return 0.0  # Handle it appropriately



# Function to calculate Adjectives
def calculate_adjectives(sentence):
    try:
        tags = pos_tag(word_tokenize(str(sentence)))
        adjective_count = sum(1 for word, tag in tags if tag.startswith('JJ'))
        return format(adjective_count / len(word_tokenize(str(sentence))),'.4f')

    except (TypeError, AttributeError) as e:
        print(f"Error in POS tagging for sentence: {sentence}. Error: {e}")
        return 0.0  # Handle it appropriately




# tf-isf
# word_dict contains the no. of times that word present in all sentences
def word_freq(sentences):
  word_dict = {}
  for sent in sentences:
    words = word_tokenize(sent)
    for word in words:
      if word not in word_dict:
        word_dict[word] = 1
      else:
        word_dict[word] += 1
  return word_dict

def tf_isf(sentences):
  word_dict = word_freq(sentences)
  n_sent = len(sentences)
  keys = word_dict.keys()
  tf_isf_score_pre_sentence = []
# isf is calculated below, later isf vales are stored back in word_dict
  for key in keys:
    x = word_dict[key]
    x = math.log(float(n_sent)/x)
    word_dict[key] = x
# temp, stores the no. of times a word appeared in sentence
  for i in range(n_sent):
    sent_val = 0
    sent = sentences[i]
    temp = {}
    words = word_tokenize(sent)
    for word in words:
      if word not in temp:
        temp[word] = 1
      else:
        temp[word] += 1

    keys = temp.keys()
    for key in keys:
      tf = float(temp[key])/len(sent)
      isf = word_dict[key]
      sent_val += (tf*isf)
    tf_isf_score_pre_sentence.append(format(sent_val,'.4f'))
    # print(tf_isf_score_pre_sentence)
  return tf_isf_score_pre_sentence
    

# Function to calculate Cosine Similarity
def cal_cosine_similarity(sentences):
    row_sum=[]
    vectorizer = TfidfVectorizer().fit_transform(sentences)
    similarity_matrix=cosine_similarity(vectorizer)
    for i in range(len(sentences)):
        temp=sum(similarity_matrix[i]) - similarity_matrix[i][i]
        row_sum.append(temp)
    max_similarity_score=max(row_sum)
    for i in range(len(row_sum)):
        
        row_sum[i]= format((float(row_sum[i])/max_similarity_score),'.4f')
    return row_sum
    
def calculate_path(x,preprocessed_file_name):
    number = re.match(r"(\d+)", preprocessed_file_name).group(1)
    return number


# Folder Paths
preprocessed_output_folder = '/home/student/Desktop/NLP_Output/final_validation_preprocess_output'
feature_output_folder = '/home/student/Desktop/NLP_Output/final_validation_feature_output'


df_feature_lis=[]


# Iterate through preprocessed files
for preprocessed_file_name in os.listdir(preprocessed_output_folder):
    preprocessed_file_path = os.path.join(preprocessed_output_folder, preprocessed_file_name)

    try:
        # Read preprocessed file into DataFrame
        df_preprocessed = pd.read_csv(preprocessed_file_path, escapechar='|', encoding='utf-8')


        # Check if the DataFrame is empty
        if df_preprocessed.empty:
            print(f"Warning: DataFrame is empty for {preprocessed_file_path}. Skipping processing.")
            continue


        # Calculate Longest Sentence Length
        longest_sentence_length =  max(df_preprocessed['preprocessed_sentence'].apply(lambda x: len(word_tokenize(x))))

        # Feature Extraction
        # print('BEFORE sentence_length nouns')
        df_preprocessed['sentence_length'] = df_preprocessed['preprocessed_sentence'].apply(
            lambda x: calculate_sentence_length(x, longest_sentence_length)
        )
        # print('AFTER sentence_length nouns')

        df_preprocessed['sentence_position'] = df_preprocessed.index.map(
            lambda x: calculate_sentence_position(x, len(df_preprocessed))
        )
        # print('AFTER sentence_position nouns')
        # print('Before proper nouns')
        df_preprocessed['proper_nouns'] = df_preprocessed['preprocessed_sentence'].apply(
            lambda x: calculate_proper_nouns(x)
        )

        # df_preprocessed['proper_noun'] =  df_preprocessed['preprocessed_sentence'].apply(lambda x: len([pos for word, pos in pos_tag(word_tokenize(x)) if pos == 'NNP']) / len(x.split()) if pd.notnull(x) and len(x.split()) != 0 else 0)

        df_preprocessed['adjectives'] = df_preprocessed['preprocessed_sentence'].apply(
            lambda x: calculate_adjectives(x)
        )

        # df_preprocessed['adjective'] = df_preprocessed.apply(lambda row: len([pos for word, pos in pos_tag(word_tokenize(row['preprocessed_sentence'])) if pos.startswith('JJ')]) / row['sentence_length'] if pd.notnull(row['preprocessed_sentence']) and row['sentence_length'] != 0 else 0, axis=1)
        
        df_preprocessed['tf_isf'] = tf_isf(df_preprocessed['preprocessed_sentence'])
        
        
        df_preprocessed['coisne_similarity']=cal_cosine_similarity(df_preprocessed['preprocessed_sentence'])
        # print('AFTER coisne_similarity nouns')
        df_preprocessed['file_name']= df_preprocessed['preprocessed_sentence'].apply(
            lambda x: calculate_path(x,preprocessed_file_name)
        )


        # Save Feature-Extracted DataFrame
        feature_file_name = f"{os.path.splitext(preprocessed_file_name)[0]}_features.csv"
        feature_file_path = os.path.join(feature_output_folder, feature_file_name)
        df_preprocessed.to_csv(feature_file_path, index=False, escapechar='|')

        print(f"{len(os.listdir(preprocessed_output_folder))}. Features extracted and saved to {feature_file_path}")
        df_feature_lis.append(df_preprocessed)

    
    except Exception as e:
        print(f"Error processing file {preprocessed_file_path}: {e}")



# Concatenate all DataFrames in the list
final_feature_df = pd.concat(df_feature_lis, ignore_index=True)

# Save the final DataFrame to a CSV file
final_feature_output_file_path = "/home/student/Desktop/NLP_Output/final_validation_feature_output_data_combined.csv"
final_feature_df.to_csv(final_feature_output_file_path, index=False, escapechar='|')

# Display the final processed DataFrame
print(f"Final processed data saved to {final_feature_output_file_path}")
# Out:
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32025_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31828_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31064_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32966_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32032_tokenized_preprocess_features.csv
# Error processing file /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30779_tokenized_preprocess.csv: expected string or bytes-like object
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32657_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30901_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/33097_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31984_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31633_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31440_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32792_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32648_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32865_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/33070_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31794_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31315_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31165_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30946_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30850_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/33154_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31846_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32042_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32149_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31517_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31038_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31939_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32408_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32190_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32229_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32107_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31914_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32343_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32392_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32651_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31546_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32531_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31568_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32140_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31654_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31478_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32359_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32424_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31685_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31508_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31220_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31969_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32452_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31109_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/33155_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31540_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30887_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32376_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30796_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31854_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31013_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30907_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30899_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31987_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31661_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30991_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31358_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31034_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32156_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/33098_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32482_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30855_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32939_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32616_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31333_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32186_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32859_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31399_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30947_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31271_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32183_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30897_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32555_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31617_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30967_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31204_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31424_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32004_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32135_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32734_tokenized_preprocess_features.csv
# Error processing file /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31146_tokenized_preprocess.csv: expected string or bytes-like object
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31506_tokenized_preprocess_features.csv
# Error processing file /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31008_tokenized_preprocess.csv: expected string or bytes-like object
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32148_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30952_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30841_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/33038_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32384_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30982_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31769_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31983_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32717_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30822_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31631_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30948_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30782_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31784_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30816_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31604_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30902_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30950_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/33029_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/33054_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30962_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31012_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30817_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31114_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32936_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31452_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31316_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32561_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32163_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31053_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32349_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32236_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32067_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32071_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32141_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32116_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32155_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/33090_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31628_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/33053_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31664_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31319_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31014_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32609_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31650_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30941_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31757_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32139_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30954_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32540_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31839_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30838_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32602_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32553_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32044_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31766_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32092_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30785_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31632_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30866_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31101_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30783_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30966_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31589_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32176_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30795_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31595_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31469_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30854_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30940_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32538_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32170_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32874_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31948_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32543_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31383_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32355_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32196_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32688_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30922_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31242_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31940_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32964_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31063_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/33083_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31224_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31074_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31474_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30800_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32556_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31655_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32223_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32197_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31620_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31277_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32129_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32849_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32886_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31105_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31955_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31265_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32217_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32248_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30830_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32623_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31061_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32954_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32021_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31462_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31979_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/33130_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31950_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31817_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/33036_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31203_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32143_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31834_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32541_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31601_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31889_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32150_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32926_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31023_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32072_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30920_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32136_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31843_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31336_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32825_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32185_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31938_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32562_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31329_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32286_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32599_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32098_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31509_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31926_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31127_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32548_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32220_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30849_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30813_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31705_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32061_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/33027_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30943_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31512_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31659_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30821_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/33018_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31058_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32034_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32848_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31872_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32179_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31306_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30858_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31015_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32157_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31844_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32113_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32854_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32134_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31274_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30886_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32144_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32773_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30874_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32165_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32168_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30913_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31970_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31202_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31076_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30895_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31514_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31857_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31022_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31634_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31290_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31959_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32389_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30904_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31942_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32879_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31059_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31040_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31363_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31824_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32557_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30903_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32545_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30927_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32693_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31678_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32583_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32340_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32345_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31677_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32809_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30968_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31033_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31007_tokenized_preprocess_features.csv
# Error processing file /home/student/Desktop/NLP_Output/final_validation_preprocess_output/32097_tokenized_preprocess.csv: expected string or bytes-like object
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31618_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31484_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30965_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31646_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31254_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31292_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31866_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31031_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31831_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31042_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30924_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31648_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32394_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30960_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32180_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32480_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/33037_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32810_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31036_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31681_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32437_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31005_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/33039_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31811_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31755_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32333_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32771_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/33057_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32051_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31026_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32020_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32378_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31260_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30820_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30808_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30888_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32560_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30856_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31851_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30852_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30819_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31623_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30777_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30781_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31492_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32380_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32272_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32177_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31567_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31513_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31050_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32597_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/33035_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31037_tokenized_preprocess_features.csv
# Error processing file /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31699_tokenized_preprocess.csv: expected string or bytes-like object
# Error processing file /home/student/Desktop/NLP_Output/final_validation_preprocess_output/30815_tokenized_preprocess.csv: expected string or bytes-like object
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31608_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30778_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31201_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32074_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32684_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31855_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31573_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31850_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/32414_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30790_tokenized_preprocess_features.csv
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/30894_tokenized_preprocess_features.csv
# Error processing file /home/student/Desktop/NLP_Output/final_validation_preprocess_output/31879_tokenized_preprocess.csv: expected string or bytes-like object
# 363. Features extracted and saved to /home/student/Desktop/NLP_Output/final_validation_feature_output/31610_tokenized_preprocess_features.csv
# Final processed data saved to /home/student/Desktop/NLP_Output/final_validation_feature_output_data_combined.csv

# %%
#  After finishing feature extraction, take the ouput and give to the trained model in file

# %%
# load the KNN model correctly, here this current ipynb file and knn model are inside same directory i.e, Home

# %%
import pandas as pd
import joblib


validation_df = pd.read_csv('/home/student/Desktop/NLP_Output/final_validation_feature_output_data_combined.csv')  # Replace with the actual file path
# Only numerical data should be given as input, so drop sentence, preprocessed_sentence
validation_df.pop('sentence')
validation_df.pop('preprocessed_sentence') 
# print(validation_df.head())
# Separate features (X) - assuming all relevant feature columns are present
X_validation = validation_df[['sentence_length', 'sentence_position', 'proper_nouns', 'adjectives', 'tf_isf', 'coisne_similarity','file_name']]

# Load the trained models

knn_model = joblib.load('knn_model.joblib')


# Make predictions using the loaded models

knn_predictions = knn_model.predict(X_validation)


# Add columns to the validation DataFrame with predicted labels

validation_df['predicted_label_knn'] = knn_predictions


# Display the modified DataFrame

validation_df.to_csv('/home/student/Desktop/NLP_Output/final_test_predicted_output.csv')

# %%
# Based on file_name as common column, we are merging validation_feature_combined, validation_fea_test_ouput_combined
# merging into validation_fea_test_ouput_combined, by this we have sentences along with predicted labels

# %%
# adding back sentence, preprocessed_sentence columns back
# kernel is getting crashed, for below part

# %%
import pandas as pd

# Assuming validation_df is already in memory
# Assuming validation_feature_combined.csv is a CSV file

# Load the CSV file into a DataFrame
validation_fea_combined = pd.read_csv('/home/student/Desktop/NLP_Output/final_validation_feature_output_data_combined.csv')  
validation_fea_combined.pop('preprocessed_sentence')
validation_fea_test_ouput_combined=pd.read_csv('/home/student/Desktop/NLP_Output/final_test_predicted_output.csv')
# validation_feature_test_ouput_combined.drop(columns=['Unnamed: 0'], inplace=True)
# Merge the dataframes based on a common column, for example, 'id'
merged_df = pd.merge(validation_fea_test_ouput_combined, validation_fea_combined[['file_name', 'sentence']], on='file_name', how='left')

# Display the merged dataframe
# print(merged_df)

merged_df.to_csv('/home/student/Desktop/NLP_Output/final_extractive_summary_output.csv')

# %%
# since kernel is getting crashes, we are doing it in chunks

# %%
import sys
sys.setrecursionlimit(10**6)

# %%
import pandas as pd

# Define the file paths
feature_combined_path = '/home/student/Desktop/NLP_Output/final_validation_feature_output_data_combined.csv'
test_output_combined_path = '/home/student/Desktop/NLP_Output/final_validation_test_predicted_output.csv'
output_csv_path = '/home/student/Desktop/NLP_Output/extractive_summary_output.csv'

# Define chunk size for reading CSV files
chunksize = 100  # Adjust this value based on your system's memory capacity

# Define an iterator to read the feature_combined CSV file in chunks
feature_combined_iter = pd.read_csv(feature_combined_path, chunksize=chunksize)

# Define an iterator to read the test_output_combined CSV file in chunks
test_output_combined_iter = pd.read_csv(test_output_combined_path, chunksize=chunksize)

# Initialize an empty list to store merged chunks
merged_chunks = []

# Iterate over both iterators simultaneously and merge the chunks
for feature_chunk, test_chunk in zip(feature_combined_iter, test_output_combined_iter):
    # Merge the chunks based on the common column 'file_name'
    merged_chunk = pd.merge(test_chunk, feature_chunk[['file_name', 'preprocessed_sentence', 'sentence']], on='file_name', how='left')
    # Append the merged chunk to the list
    merged_chunks.append(merged_chunk)

# Concatenate all merged chunks into a single DataFrame
merged_df = pd.concat(merged_chunks)

# Display the merged dataframe
print(merged_df)

# Save the merged dataframe to a new CSV file
merged_df.to_csv(output_csv_path, index=False)
# Out:
#       Unnamed: 0  sentence_length  sentence_position  proper_nouns  \
# 0              0           0.1143                1.0        0.5000
# 1              0           0.1143                1.0        0.5000
# 2              0           0.1143                1.0        0.5000
# 3              0           0.1143                1.0        0.5000
# 4              0           0.1143                1.0        0.5000
# ...          ...              ...                ...           ...
# 8095      686289           0.0078                1.0        0.6923
# 8096      686289           0.0078                1.0        0.6923
# 8097      686289           0.0078                1.0        0.6923
# 8098      686289           0.0078                1.0        0.6923
# 8099      686289           0.0078                1.0        0.6923
#
#       adjectives  tf_isf  coisne_similarity  file_name  predicted_label_knn  \
# 0         0.0385  0.4901             0.5990      32025                  0.0
# 1         0.0385  0.4901             0.5990      32025                  0.0
# 2         0.0385  0.4901             0.5990      32025                  0.0
# 3         0.0385  0.4901             0.5990      32025                  0.0
# 4         0.0385  0.4901             0.5990      32025                  0.0
# ...          ...     ...                ...        ...                  ...
# 8095      0.0769  0.4368             0.4597      31610                  0.0
# 8096      0.0769  0.4368             0.4597      31610                  0.0
# 8097      0.0769  0.4368             0.4597      31610                  0.0
# 8098      0.0769  0.4368             0.4597      31610                  0.0
# 8099      0.0769  0.4368             0.4597      31610                  0.0
#
#                                   preprocessed_sentence  \
# 0     NWF Group plc Annual Report Accounts 2017 ANNU...
# 1     aim deliver total shareholder return continued...
# 2     Read glance spread Pages 2 3 INVESTING FEEDS F...
# 3     Good second half recovery impacted margin pres...
# 4     Volumes robust mill development North Cheshire...
# ...                                                 ...
# 8095  Shareholdings 30 September 2017 Ordinary Share...
# 8096  Contact Details DMGT Head Office Northcliffe H...
# 8097         Printed UK Pureprint CarbonNeutral company
# 8098  manufacturing mill printer registered Environm...
# 8099  Design production Governance Financial Stateme...
#
#                                                sentence
# 0      NWF Group plc Annual Report and Accounts 2017...
# 1     Our aim is to deliver total shareholder return...
# 2     Read our At a glance spread on Pages 2 and 3\n...
# 3     Good second half recovery, \nhaving been impac...
# 4     Volumes were robust and the \nmill development...
# ...                                                 ...
# 8095  Shareholdings at 30 September 2017\nOrdinary S...
# 8096  Contact Details\nDMGT Head Office \nNorthcliff...
# 8097  Printed in the UK by Pureprint who are \na Car...
# 8098  Both manufacturing mill and the printer are \n...
# 8099  Design and production \nGovernance Financial S...
#
# [67430924 rows x 11 columns]

# %%
# take the predicted output, trying to generate summary

# %%
import pandas as pd
import os
import re
# Load the CSV file
csv_file_path = '/home/student/Desktop/NLP_Output/extractive_summary_output.csv'
df = pd.read_csv(csv_file_path)

word_number_pattern = re.compile(r'\b\w+\b')

# Filter rows where label is equal to 1
df_positive_labels = df[df['predicted_label_knn'] == 1]

# Create a directory to store the output files
output_directory = '/home/student/Desktop/NLP_Output/final_KNN_summary_word_res_(sent)'
os.makedirs(output_directory, exist_ok=True)

# Group by 'file_name' and iterate through each group
for file_name, group_df in df_positive_labels.groupby('file_name'):
    # Create a text file with the same name as the 'file_name' inside the output directory
    output_file_path = os.path.join(output_directory, 'fns'+str(file_name)+'_'+str(file_name)+'.txt')

    word_count = 0
    summary = ""
    with open(output_file_path, 'w', encoding='utf-8') as file:
      for sentence in group_df['sentence']:
        # Split the sentence into words including numbers
        words = word_number_pattern.findall(sentence)
        # Check if adding the current sentence would exceed the word limit
        for word in words:
            # Increment word count for each word including numbers
            word_count += 1
            if word_count <= 1000:
                summary += word + ' '  # Append the word to the summary
            else:
                break  # Exit the loop if the word limit is reached
        else:
             summary = summary.strip()+'. '
             continue  # Continue to the next sentence if the word limit is not reached
        break  # Exit the loop if the word limit is reached

    # Write the summary to the file
      file.write(summary)

# Print a message indicating the process is complete
print("Text files generated successfully in the 'output_files' directory.")
# Out:
# Text files generated successfully in the 'output_files' directory.

# %%
# /home/student/Desktop/FNS_dataset/validation/System , here inside System folder,upload the generated summaries of KNN

# %%
# Now run the rouge jar file and see the results in results.csv file inside v1.2.2

# %%
# calculating avg of rouge

# %%
import pandas as pd



# Load the CSV file into a DataFrame
file_path = '/home/student/Desktop/rouge2_v1.2.2_runnable/v1.2.2/results.csv'
df = pd.read_csv(file_path)

# Filter rows where ROUGE-Type is 'ROUGE-L+StopWordRemoval'
rouge_l_stopword_removal_df = df[df['ROUGE-Type'] == 'ROUGE-L+StopWordRemoval']

# Calculate the average values
average_avg_recall = rouge_l_stopword_removal_df['Avg_Recall'].mean()
average_avg_precision = rouge_l_stopword_removal_df['Avg_Precision'].mean()
average_avg_f_score = rouge_l_stopword_removal_df['Avg_F-Score'].mean()

# Add new columns to the original DataFrame
df['Average of ROUGE-L+StopWordRemoval in Avg_Recall'] = average_avg_recall
df['Average of ROUGE-L+StopWordRemoval in Avg_Precision'] = average_avg_precision
df['Average of ROUGE-L+StopWordRemoval in Avg_F-Score'] = average_avg_f_score

# Save the modified DataFrame back to the original CSV file
output_file_path = '/home/student/Desktop/NLP_Output/final_avg_knn_rouge.csv'
df.to_csv(output_file_path, index=False)

print("Average Avg_Recall:", average_avg_recall)
print("Average Avg_Precision:", average_avg_precision)
print("Average Avg_F-Score:", average_avg_f_score)
print("New CSV file with additional average columns has been saved.")
# Out:
# Average Avg_Recall: 0.5319071428571428
# Average Avg_Precision: 0.49219285714285715
# Average Avg_F-Score: 0.5009657142857142
# New CSV file with additional average columns has been saved.
